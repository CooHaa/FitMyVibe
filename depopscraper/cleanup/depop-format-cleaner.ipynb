# %%
import json

# Load your JSON file
with open("depop-mens-bottoms.json", "r") as f:
    data = json.load(f)

# Add category_name as "Bottoms" to each item
for item in data:
    item["category_name"] = "Bottoms"

# Save it to a new file
with open("depop-bottoms-with-category.json", "w") as f:
    json.dump(data, f, indent=2)

print("All entries updated with 'category_name: Bottoms'")
# Out:
# All entries updated with 'category_name: Bottoms'

# %%
# Out:
# [{'url': 'https://www.depop.com/products/_kopesthrift-vintage-wrangler-relaxed-fit-jeans/?moduleOrigin=meganav', 'title': 'vintage wrangler relaxed fit jeans', 'price': '10.00', 'currency': 'USD', 'image': 'https://media-photos.depop.com/b1/40555710/2605653291_fa251542ff604e6088477c3aa5671b8c/P10.jpg', 'seller': '_kopesthrift', 'detailed': {'productName': 'Vintage Wrangler relaxed fit jeans \n38x30\n\n#wrangler...', 'brand': 'Wrangler', 'price': '10.00', 'currency': 'USD', 'description': 'Vintage Wrangler relaxed fit jeans \n38x30\n\n#wrangler #vintage #jeans #streetwear', 'image': ['https://media-photos.depop.com/b1/40555710/2605653291_fa251542ff604e6088477c3aa5671b8c/P0.jpg', 'https://media-photos.depop.com/b1/40555710/2605653301_57d69a5e27b14f19a304a1489f238cf1/P0.jpg', 'https://media-photos.depop.com/b1/40555710/2605649647_c7e801a9551648eab8a364c28afd1501/P0.jpg'], 'availability': 'https://schema.org/InStock', 'seller': '_kopesthrift', 'size': None}, 'structuredData': {'name': 'Vintage Wrangler relaxed fit jeans \n38x30\n\n#wrangler...', 'description': 'Vintage Wrangler relaxed fit jeans \n38x30\n\n#wrangler #vintage #jeans #streetwear', '@context': 'https://schema.org', '@type': 'Product', 'image': ['https://media-photos.depop.com/b1/40555710/2605653291_fa251542ff604e6088477c3aa5671b8c/P0.jpg', 'https://media-photos.depop.com/b1/40555710/2605653301_57d69a5e27b14f19a304a1489f238cf1/P0.jpg', 'https://media-photos.depop.com/b1/40555710/2605649647_c7e801a9551648eab8a364c28afd1501/P0.jpg'], 'brand': {'@type': 'Brand', 'name': 'Wrangler'}, 'offers': {'@type': 'Offer', 'url': 'https://www.depop.com/products/_kopesthrift-vintage-wrangler-relaxed-fit-jeans/', 'priceCurrency': 'USD', 'price': '10.00', 'availability': 'https://schema.org/InStock', 'itemCondition': 'https://schema.org/UsedCondition'}}, 'category_name': 'Bottoms'}, {'url': 'https://www.depop.com/products/bryceg123onnabeat-blue-vf-outlet-carpenter-jeans/?moduleOrigin=meganav', 'title': 'blue vf outlet carpenter jeans', 'price': '16.50', 'currency': 'USD', 'image': 'https://media-photos.depop.com/b1/469255692/2609984527_0fdad616302542c6bd382c461f0cd486/P10.jpg', 'seller': 'bryceg123onnabeat', 'detailed': {'productName': 'Blue VF Outlet carpenter jeans jeans wrangler...', 'brand': 'Wrangler', 'price': '16.50', 'currency': 'USD', 'description': 'Blue VF Outlet carpenter jeans jeans wrangler carpenter jeans size 36x32 #vintage #baggyfit #madeinusa #y2kfashion #truevintage', 'image': ['https://media-photos.depop.com/b1/469255692/2609984527_0fdad616302542c6bd382c461f0cd486/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984523_cfcd2b9ab7834361b0b4facaca959e5a/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984525_029462e3ecf6440ca6fddaabdb2dad81/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984524_e81a59297e3f475c80bad963947f8649/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984526_40e0ccc38b0e415db97215036c24e5f7/P0.jpg'], 'availability': 'https://schema.org/InStock', 'seller': 'bryceg123onnabeat', 'size': '36x32'}, 'structuredData': {'name': 'Blue VF Outlet carpenter jeans jeans wrangler...', 'description': 'Blue VF Outlet carpenter jeans jeans wrangler carpenter jeans size 36x32 #vintage #baggyfit #madeinusa #y2kfashion #truevintage', '@context': 'https://schema.org', '@type': 'Product', 'image': ['https://media-photos.depop.com/b1/469255692/2609984527_0fdad616302542c6bd382c461f0cd486/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984523_cfcd2b9ab7834361b0b4facaca959e5a/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984525_029462e3ecf6440ca6fddaabdb2dad81/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984524_e81a59297e3f475c80bad963947f8649/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984526_40e0ccc38b0e415db97215036c24e5f7/P0.jpg'], 'brand': {'@type': 'Brand', 'name': 'Wrangler'}, 'offers': {'@type': 'Offer', 'url': 'https://www.depop.com/products/bryceg123onnabeat-blue-vf-outlet-ca ...

# %%
# # DEFINE CLOTHING FUNCTIONS
# def get_category_names(items):
#     """
#     Given a list of dicts, return a list of all 'category_name' values.
#     """
#     return [item.get("category_name") for item in items]

# def get_unique_category_names(items):
#     """
#     Given a list of dicts, return a list of all unique 'category_name' values.
#     """
#     return list(set(get_category_names(items)))

# def get_clothing_categories(category_names):
#     """
#     Filters the category names to only include clothing-related items.
#     """
#     # Define a list of keywords related to clothing
#     clothing_keywords = ["shirt", "pants", "dress", "jacket", "jeans", "sweater", "hoodie", "shorts", "skirt", "blouse", "coat", "suit", "t-shirt", "top", "clothing", "apparel", 'accessory', 'footwear', 'activewear', 'outerwear', 'underwear', 'lingerie', 'swimwear', 'sneakers', 'boots', 'sandals', 'flip-flops', 'slippers', 'pajamas', 'loungewear', 'robe', 'jumpsuit', 'romper', 'overalls', 'leggings', 'tights', 'stockings', 'socks', 'scarf', 'hat', 'beanie', 'cap', 'gloves', 'men', 'women']

#     # Filter category names that contain any of the clothing-related keywords
#     clothing_categories = [category for category in category_names if any(keyword in category.lower() for keyword in clothing_keywords)]
    
#     return clothing_categories

# %%
# category_names = get_unique_category_names(data)
# print("Total number of categories:", len(category_names))
# # print(category_names)

# clothing_categories = get_clothing_categories(category_names)
# print("Total number of clothing categories:", len(clothing_categories))
# Out:
# Total number of categories: 1
# Total number of clothing categories: 0

# %%
print(data)
# Out:
# [{'url': 'https://www.depop.com/products/_kopesthrift-vintage-wrangler-relaxed-fit-jeans/?moduleOrigin=meganav', 'title': 'vintage wrangler relaxed fit jeans', 'price': '10.00', 'currency': 'USD', 'image': 'https://media-photos.depop.com/b1/40555710/2605653291_fa251542ff604e6088477c3aa5671b8c/P10.jpg', 'seller': '_kopesthrift', 'detailed': {'productName': 'Vintage Wrangler relaxed fit jeans \n38x30\n\n#wrangler...', 'brand': 'Wrangler', 'price': '10.00', 'currency': 'USD', 'description': 'Vintage Wrangler relaxed fit jeans \n38x30\n\n#wrangler #vintage #jeans #streetwear', 'image': ['https://media-photos.depop.com/b1/40555710/2605653291_fa251542ff604e6088477c3aa5671b8c/P0.jpg', 'https://media-photos.depop.com/b1/40555710/2605653301_57d69a5e27b14f19a304a1489f238cf1/P0.jpg', 'https://media-photos.depop.com/b1/40555710/2605649647_c7e801a9551648eab8a364c28afd1501/P0.jpg'], 'availability': 'https://schema.org/InStock', 'seller': '_kopesthrift', 'size': None}, 'structuredData': {'name': 'Vintage Wrangler relaxed fit jeans \n38x30\n\n#wrangler...', 'description': 'Vintage Wrangler relaxed fit jeans \n38x30\n\n#wrangler #vintage #jeans #streetwear', '@context': 'https://schema.org', '@type': 'Product', 'image': ['https://media-photos.depop.com/b1/40555710/2605653291_fa251542ff604e6088477c3aa5671b8c/P0.jpg', 'https://media-photos.depop.com/b1/40555710/2605653301_57d69a5e27b14f19a304a1489f238cf1/P0.jpg', 'https://media-photos.depop.com/b1/40555710/2605649647_c7e801a9551648eab8a364c28afd1501/P0.jpg'], 'brand': {'@type': 'Brand', 'name': 'Wrangler'}, 'offers': {'@type': 'Offer', 'url': 'https://www.depop.com/products/_kopesthrift-vintage-wrangler-relaxed-fit-jeans/', 'priceCurrency': 'USD', 'price': '10.00', 'availability': 'https://schema.org/InStock', 'itemCondition': 'https://schema.org/UsedCondition'}}, 'category_name': 'Bottoms'}, {'url': 'https://www.depop.com/products/bryceg123onnabeat-blue-vf-outlet-carpenter-jeans/?moduleOrigin=meganav', 'title': 'blue vf outlet carpenter jeans', 'price': '16.50', 'currency': 'USD', 'image': 'https://media-photos.depop.com/b1/469255692/2609984527_0fdad616302542c6bd382c461f0cd486/P10.jpg', 'seller': 'bryceg123onnabeat', 'detailed': {'productName': 'Blue VF Outlet carpenter jeans jeans wrangler...', 'brand': 'Wrangler', 'price': '16.50', 'currency': 'USD', 'description': 'Blue VF Outlet carpenter jeans jeans wrangler carpenter jeans size 36x32 #vintage #baggyfit #madeinusa #y2kfashion #truevintage', 'image': ['https://media-photos.depop.com/b1/469255692/2609984527_0fdad616302542c6bd382c461f0cd486/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984523_cfcd2b9ab7834361b0b4facaca959e5a/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984525_029462e3ecf6440ca6fddaabdb2dad81/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984524_e81a59297e3f475c80bad963947f8649/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984526_40e0ccc38b0e415db97215036c24e5f7/P0.jpg'], 'availability': 'https://schema.org/InStock', 'seller': 'bryceg123onnabeat', 'size': '36x32'}, 'structuredData': {'name': 'Blue VF Outlet carpenter jeans jeans wrangler...', 'description': 'Blue VF Outlet carpenter jeans jeans wrangler carpenter jeans size 36x32 #vintage #baggyfit #madeinusa #y2kfashion #truevintage', '@context': 'https://schema.org', '@type': 'Product', 'image': ['https://media-photos.depop.com/b1/469255692/2609984527_0fdad616302542c6bd382c461f0cd486/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984523_cfcd2b9ab7834361b0b4facaca959e5a/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984525_029462e3ecf6440ca6fddaabdb2dad81/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984524_e81a59297e3f475c80bad963947f8649/P0.jpg', 'https://media-photos.depop.com/b1/469255692/2609984526_40e0ccc38b0e415db97215036c24e5f7/P0.jpg'], 'brand': {'@type': 'Brand', 'name': 'Wrangler'}, 'offers': {'@type': 'Offer', 'url': 'https://www.depop.com/products/bryceg123onnabeat-blue-vf-outlet-ca ...

# %%
# def filter_and_reformat(data, clothing_categories):
#     """
#     Filters items from the JSON data that belong to the clothing categories,
#     removes items with descriptions of fewer than 10 words, and reformats
#     the JSON attributes to the specified structure.
#     """
#     reformatted_items = []
#     for item in data:
#         # Check if the category is in the clothing categories list
#         if item.get("category_name", "").lower() not in [category.lower() for category in clothing_categories]:
#             continue

#         # Check if the description exists and has at least 10 words
#         description = item.get("item_description", "")
#         if len(description.split()) < 10:
#             continue

#         # Set gender based on category name
#         if "women" in item.get("category_name", "").lower() or "girl" in item.get("category_name", "").lower() or "womenswear" in item.get("category_name", "").lower(): 
#             item["gender_from_category"] = "f"
#         elif "men" in item.get("category_name", "").lower() or "boy" in item.get("category_name", "").lower() or "menswear" in item.get("category_name", "").lower(): 
#             item["gender_from_category"] = "m"

#         # Reformat the item
#         reformatted_item = {
#             "ID": item.get("ID"),
#             "name": item.get("name"),
#             "description": description,
#             "category": item.get("category_name", ""),
#             "brand": item.get("brand_name", ""),
#             "gender": item.get("gender_from_category", "u"), # Default to 'unisex' if 'gender' is missing
#             "price": item.get("price"),
#             "prodLink": item.get("prodLink", ""), 
#             "prodImgLink": item.get("prodImgLink", "")
#         }
#         reformatted_items.append(reformatted_item)
#     return reformatted_items

# new_json_list = filter_and_reformat(data, clothing_categories)
# print("Total number of clothing items:", len(new_json_list))

def filter_and_reformat(data):
    """
    Processes items by:
    - Filtering out items with descriptions under 10 words.
    - Hardcoding category as 'Bottoms'.
    - Adding gender as unisex.
    - Returning the reformatted structure.
    """
    reformatted_items = []
    for i, item in enumerate(data):
        # Check if the description exists and has at least 10 words
        description = item.get("detailed", {}).get("description", "")
        if len(description.split()) < 10:
            continue

        reformatted_item = {
            "ID": i,  # You can change this if you have real IDs
            "name": item.get("title", ""),
            "description": description,
            "category": "Bottoms",
            "brand": item.get("detailed", {}).get("brand", ""),
            "gender": "u",  # All items default to unisex unless specified
            "price": item.get("price"),
            "prodLink": item.get("url", ""),
            "prodImgLink": item.get("image", "")
        }

        reformatted_items.append(reformatted_item)

    return reformatted_items


new_json_list = filter_and_reformat(data)
print("Total number of clothing items:", len(new_json_list))
# Out:
# Total number of clothing items: 75

# %%
with open('new-depop-mens-bottoms.json', "w") as file:
    json.dump(new_json_list, file, indent=4)

# %%
# UPDATE PRODUCT IDS
def update_product_ids(data):
    """
    Updates the product IDs in the JSON data such that the first ID is 0,
    and each subsequent ID increments by 1.
    """
    for new_id, item in enumerate(data):
        item["ID"] = new_id  # Update the product ID
    return data

# Load the JSON data from the file
input_file_path = "new-depop-mens-bottoms.json"
with open(input_file_path, "r") as file:
    data = json.load(file)

# Update product IDs
updated_data = update_product_ids(data)

# Save the updated JSON data back to the same file
with open(input_file_path, "w") as file:
    json.dump(updated_data, file, indent=4)

# %%
# Function to append processed data to the existing JSON file
def process_and_append_to_file(existing_file_path, new_file_path, clothing_categories):
    """
    Processes a new JSON file, applies filtering and reformatting, and appends
    the results to an existing JSON file without overwriting the previous data.
    """
    # Step 1: Load the existing data from the existing file
    try:
        with open(existing_file_path, "r") as file:
            existing_data = json.load(file)
    except FileNotFoundError:
        existing_data = []

    # Step 2: Load the new data from the new file
    with open(new_file_path, "r") as file:
        new_data = json.load(file)

    # Step 3: Process the new data using the filter_and_reformat function
    processed_new_data = filter_and_reformat(new_data, clothing_categories)

    # Step 4: Append the processed new data to the existing data
    existing_data.extend(processed_new_data)

    # Step 5: Save the combined data back to the existing file
    with open(existing_file_path, "w") as file:
        json.dump(existing_data, file, indent=4)

    print(f"Appended {len(processed_new_data)} new items to {existing_file_path}.")

# # Example usage
# existing_file_path = "new-mercari-set1.json"
# new_file_path = "mercari-set2.json" 
# process_and_append_to_file(existing_file_path, new_file_path, clothing_categories)
